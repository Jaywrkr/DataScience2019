# %% [markdown]
# # Data Exploration - Chronic Kidney Disease
# We perform the exploration of the Chronic Kidney Disease dataset we preprocessed for missing values before.

# %%
# dataframe management
import pandas as pd             

# numerical computation
import numpy as np

# visualization library
import seaborn as sns
sns.set(style="white", color_codes=True)
sns.set_context(rc={"font.family":'sans',"font.size":24,"axes.titlesize":24,"axes.labelsize":24})   


# import matplotlib and allow it to plot inline
import matplotlib.pyplot as plt
# %matplotlib inline

# seaborn can generate several warnings, we ignore them
import warnings 
warnings.filterwarnings("ignore")

# %% [markdown]
# Let's load the Iris dataset

# %%
df = pd.read_csv('ChronicKidneyDiseaseImputed.csv')

df.head(5)
# Out:
#     age    bp     sg   al   su    bgr    bu   sc    sod  pot  ...         pc  \
# 0  48.0  80.0  1.020  1.0  0.0  121.0  36.0  1.2  138.0  4.4  ...     normal
# 1   7.0  50.0  1.020  4.0  0.0  121.0  18.0  0.8  138.0  4.4  ...     normal
# 2  62.0  80.0  1.010  2.0  3.0  423.0  53.0  1.8  138.0  4.4  ...     normal
# 3  48.0  70.0  1.005  4.0  0.0  117.0  56.0  3.8  111.0  2.5  ...   abnormal
# 4  51.0  80.0  1.010  2.0  0.0  106.0  26.0  1.4  138.0  4.4  ...     normal
#
#           pcc          ba  htn   dm cad appet   pe  ane class
# 0  notpresent  notpresent  yes  yes  no  good   no   no   ckd
# 1  notpresent  notpresent   no   no  no  good   no   no   ckd
# 2  notpresent  notpresent   no  yes  no  poor   no  yes   ckd
# 3     present  notpresent  yes   no  no  poor  yes  yes   ckd
# 4  notpresent  notpresent   no   no  no  good   no   no   ckd
#
# [5 rows x 25 columns]

# %% [markdown]
# Let's get some statistics for continuous attributes

# %%
df.describe()
# Out:
#               age          bp          sg         al          su         bgr  \
# count  400.000000  400.000000  400.000000  400.00000  400.000000  400.000000
# mean    51.562500   76.575000    1.017712    0.90000    0.395000  145.062500
# std     16.982996   13.489785    0.005434    1.31313    1.040038   75.260774
# min      2.000000   50.000000    1.005000    0.00000    0.000000   22.000000
# 25%     42.000000   70.000000    1.015000    0.00000    0.000000  101.000000
# 50%     55.000000   80.000000    1.020000    0.00000    0.000000  121.000000
# 75%     64.000000   80.000000    1.020000    2.00000    0.000000  150.000000
# max     90.000000  180.000000    1.025000    5.00000    5.000000  490.000000
#
#                bu          sc         sod         pot       hemo         pcv  \
# count  400.000000  400.000000  400.000000  400.000000  400.00000  400.000000
# mean    56.693000    2.997125  137.631250    4.577250   12.54250   39.082500
# std     49.395258    5.628886    9.206332    2.821357    2.71649    8.162245
# min      1.500000    0.400000    4.500000    2.500000    3.10000    9.000000
# 25%     27.000000    0.900000  135.000000    4.000000   10.87500   34.000000
# 50%     42.000000    1.300000  138.000000    4.400000   12.65000   40.000000
# 75%     61.750000    2.725000  141.000000    4.800000   14.62500   44.000000
# max    391.000000   76.000000  163.000000   47.000000   17.80000   54.000000
#
#                wbcc        rbcc
# count    400.000000  400.000000
# mean    8298.500000    4.737750
# std     2529.593814    0.841439
# min     2200.000000    2.100000
# 25%     6975.000000    4.500000
# 50%     8000.000000    4.800000
# 75%     9400.000000    5.100000
# max    26400.000000    8.000000

# %% [markdown]
# And some statistics about the class attribute Species

# %%
df.describe(exclude=[np.number])
# Out:
#            rbc      pc         pcc          ba  htn   dm  cad appet   pe  ane  \
# count      400     400         400         400  400  400  400   400  400  400
# unique       2       2           2           2    2    2    2     2    2    2
# top     normal  normal  notpresent  notpresent   no   no   no  good   no   no
# freq       353     324         358         378  253  263  366   318  324  340
#
#        class
# count    400
# unique     2
# top      ckd
# freq     250

# %%
categorical_variables_mask = df.dtypes==object
categorical_variables = df.columns[categorical_variables_mask].tolist()
categorical_variables.remove('class')
numerical_variables = df.columns[~categorical_variables_mask]

# %% [markdown]
# We can compute correlations among attributes.

# %%
cov=df[numerical_variables].corr(method='pearson')
plt.figure(figsize = (16,16))
sns.heatmap(cov,square=True,annot=True,cmap="Blues",cbar=True,xticklabels=True, yticklabels=True)

# %% [markdown]
# We can further analyze the relations among variables by using clustermaps on the correlation matrix

# %%
cm = sns.clustermap(cov, annot=True, center=0, cmap="Blues", figsize=(12, 12))
cm.cax.set_visible(False)

# %% [markdown]
# Or over the original dataset

# %%
cm = sns.clustermap(df[numerical_variables], annot=False, center=0, cmap="Blues", figsize=(18, 18))
cm.cax.set_visible(False)

# %% [markdown]
# We check how features vary with each data input

# %%
plt.figure(figsize=(10,8))
for v in numerical_variables:
    plt.plot(df[v])
plt.legend(loc='best')

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler().fit(df[numerical_variables])
df_normalized_values = scaler.transform(df[numerical_variables])
df_normalized = pd.DataFrame(data = df_normalized_values, columns=numerical_variables)
df_normalized.head()
# Out:
#         age        bp        sg        al        su       bgr        bu  \
# 0 -0.210031  0.254214  0.421486  0.076249 -0.380269 -0.320122 -0.419451
# 1 -2.627234 -1.972476  0.421486  2.363728 -0.380269 -0.320122 -0.784315
# 2  0.615355  0.254214 -1.421074  0.838742  2.507853  3.697618 -0.074858
# 3 -0.210031 -0.488016 -2.342354  2.363728 -0.380269 -0.373337 -0.014047
# 4 -0.033163  0.254214 -1.421074  0.838742 -0.380269 -0.519679 -0.622154
#
#          sc       sod       pot      hemo       pcv      wbcc      rbcc
# 0 -0.319668  0.040104 -0.062903  1.053226  0.603224 -0.197314  0.550044
# 1 -0.390819  0.040104 -0.062903 -0.457965 -0.132789 -0.909782  0.074073
# 2 -0.212942  0.040104 -0.062903 -1.084556 -0.991470 -0.316059  0.074073
# 3  0.142813 -2.896333 -0.737181 -0.494823 -0.868801 -0.632711 -0.996862
# 4 -0.284093  0.040104 -0.062903 -0.347390 -0.500795 -0.395222 -0.163913

# %%
plt.figure(figsize=(10,8))
for v in numerical_variables:
    plt.plot(df_normalized[v])
plt.legend(loc='best')

# %% [markdown]
# For each class value we compute the mean values and plot them using a bar plot.

# %%
plt.figure(figsize=(4,len(numerical_variables)*5))
for i,v in enumerate(numerical_variables):
    plt.subplot(len(numerical_variables), 1, i+1)
    hist1 = sns.distplot(df[v],bins=5)

# %% [markdown]
# We can plot the distribution for each class.

# %%
numerical_variables_with_class = numerical_variables.tolist()
numerical_variables_with_class.append('class')

sns.FacetGrid(df[numerical_variables_with_class], hue="class", size=6) \
   .map(sns.kdeplot, "age") \
   .add_legend()

# %%
plt.figure(figsize=(6,len(numerical_variables)*4))
for i,v in enumerate(numerical_variables):
    sns.FacetGrid(df[numerical_variables_with_class], hue="class", size=6) \
   .map(sns.kdeplot, v) \
   .add_legend()

# %% [markdown]
# And now we use scatter plots.

# %%
sns.pairplot(df[numerical_variables_with_class], x_vars=["age"], y_vars=["bp"], hue="class", size=5) \
   .add_legend()

# %%
sns.pairplot(df[numerical_variables_with_class], x_vars=["age"], y_vars=["hemo"], hue="class", size=5) \
   .add_legend()

# %% [markdown]
# We can combine histograms and histograms in the same figure.

# %%
colors = {'ckd':'r', 'notckd':'b'}
sns.set_context("notebook", font_scale=1.5, rc={"lines.linewidth": 2.5})
sns.jointplot(x="sc", y="bu", data=df[df[numerical_variables_with_class]['class']=='ckd'], color='red', size=6)
sns.jointplot(x="sc", y="bu", data=df[df[numerical_variables_with_class]['class']=='notckd'], color='blue', size=6)

# %%
sns.set_context("notebook", font_scale=1.5, rc={"lines.linewidth": 1})
sns.boxplot(x="class", y="age", data=df[numerical_variables_with_class])

# %% [markdown]
# We can also add the scatter plot for every boxplot.

# %%
sns.set_context("notebook", font_scale=1.5, rc={"lines.linewidth": 1})
ax = sns.boxplot(x="class", y="age", data=df[numerical_variables_with_class])
ax = sns.stripplot(x="class", y="age", data=df[numerical_variables_with_class], jitter=True, edgecolor="gray")

# %% [markdown]
# We can plot the scatter plots for the pairwise attribute combinations.

# %%
sns.pairplot(df, hue="class", size=3,diag_kind="kde")

# %% [markdown]
# We can replace the diagonal bar plots with a gaussian kernel density estimate.

# %% [markdown]
# Similarly we can do the same for boxplots.

# %%
df_normalized['class'] = df['class']
plt.figure(figsize=(4,len(numerical_variables)*4))
for i,v in enumerate(numerical_variables):
    plt.subplot(len(numerical_variables), 1, i+1)
    sns.boxplot(data=df_normalized[numerical_variables_with_class], x='class', y = v)

# %% [markdown]
# ## Principal Component Analysis

# %% [markdown]
# So far we used only some data dimensions for visualization. We now apply Principal Component Analysis to project the four original dimensions into a two dimensional space.

# %%
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

# %%
x = df.loc[:, numerical_variables].values
y = df.loc[:,['class']].values

y
# Out:
# array([['ckd'],
#        ['ckd'],
#        ['ckd'],
#        ['ckd'],
#        ['ckd'],
#        ['ckd'],
#        ['ckd'],
#        ['ckd'],
#        ['ckd'],
#        ['ckd'],
#        ['ckd'],
#        ['ckd'],
#        ['ckd'],
#        ['ckd'],
#        ['ckd'],
#        ['ckd'],
#        ['ckd'],
#        ['ckd'],
#        ['ckd'],
#        ['ckd'],
#        ['ckd'],
#        ['ckd'],
#        ['ckd'],
#        ['ckd'],
#        ['ckd'],
#        ['ckd'],
#        ['ckd'],
#        ['ckd'],
#        ['ckd'],
#        ['ckd'],
#        ['ckd'],
#        ['ckd'],
#        ['ckd'],
#        ['ckd'],
#        ['ckd'],
#        ['ckd'],
#        ['ckd'],
#        ['ckd'],
#        ['ckd'],
#        ['ckd'],
#        ['ckd'],
#        ['ckd'],
#        ['ckd'],
#        ['ckd'],
#        ['ckd'],
#        ['ckd'],
#        ['ckd'],
#        ['ckd'],
#        ['ckd'],
#        ['ckd'],
#        ['ckd'],
#        ['ckd'],
#        ['ckd'],
#        ['ckd'],
#        ['ckd'],
#        ['ckd'],
#        ['ckd'],
#        ['ckd'],
#        ['ckd'],
#        ['ckd'],
#        ['ckd'],
#        ['ckd'],
#        ['ckd'],
#        ['ckd'],
#        ['ckd'],
#        ['ckd'],
#        ['ckd'],
#        ['ckd'],
#        ['ckd'],
#        ['ckd'],
#        ['ckd'],
#        ['ckd'],
#        ['ckd'],
#        ['ckd'],
#        ['ckd'],
#        ['ckd'],
#        ['ckd'],
#        ['ckd'],
#        ['ckd'],
#        ['ckd'],
#        ['ckd'],
#        ['ckd'],
#        ['ckd'],
#        ['ckd'],
#        ['ckd'],
#        ['ckd'],
#        ['ckd'],
#        ['ckd'],
#        ['ckd'],
#        ['ckd'],
#        ['ckd'],
#        ['ckd'],
#        ['ckd'],
#        ['ckd'],
#        ['ckd'],
#        ['ckd'],
#        ['ckd'],
#        ['ckd'],
#        ['ckd'],
#        ['ckd'],
#        ['ckd'],
#        ['ckd'],
#        ['ckd'],
#        ['ckd'],
#        ['ckd'],
#        ['ckd'],
#        ['ckd'],
#        ['ckd'],
#        ['ckd'],
#        ['ckd'],
#        ['ckd'],
#        ['ckd'],
#        ['ckd'],
#        ['ckd'],
#        ['ckd'],
#        ['ckd'],
#        ['ckd'],
#        ['ckd'],
#        ['ckd'],
#        ['ckd'],
#        ['ckd'],
#        ['ckd'],
#        ['ckd'],
#        ['ckd'],
#        ['ckd'],
#        ['ckd'],
#        ['ckd'],
#        ['ckd'],
#        ['ckd'],
#        ['ckd'],
#        ['ckd'],
#        ['ckd'],
#        ['ckd'],
#        ['ckd'],
#        ['ckd'],
#        ['ckd'],
#        ['ckd'],
#        ['ckd'],
#        ['ckd'],
#        ['ckd'],
#        ['ckd'],
#        ['ckd'],
#        ['ckd'],
#        ['ckd'],
#        ['ckd'],
#        ['ckd'],
#        ['ckd'],
#        ['ckd'],
#        ['ckd'],
#        ['ckd'],
#        ['ckd'],
#        ['ckd'],
#        ['ckd'],
#        ['ckd'],
#        ['ckd'],
#        ['ckd'],
#        ['ckd'],
#        ['ckd'],
#        ['ckd'],
#        ['ckd'],
#        ['ckd'],
#        ['ckd'],
#        ['ckd'],
#        ['ckd'],
#        ['ckd'],
#        ['ckd'],
#        ['ckd'],
#        ['ckd'],
#        ['ckd'],
#        ['ckd'],
#        ['ckd'],
#        ['ckd'],
#        ['ckd'],
#        ['ckd'],
#        ['ckd'],
#        ['ckd'],
#        ['ckd'],
#        ['ckd'],
#        ['ckd'],
#        ['ckd'],
#        ['ckd'],
#        ['ckd'],
#        ['ckd'],
#        ['ckd'],
#        ['ckd'],
#        ['ckd'],
#        ['ckd'],
#        ['ckd'],
#        ['ckd'],
#        ['ckd'],
#        ['ckd'],
#        ['ckd'],
#        ['ckd'],
#        ['ckd'],
#        ['ckd'],
#        ['ckd'],
#        ['ckd'],
#        ['ckd'],
#        ['ckd'],
#        ['ckd'],
#        ['ckd'],
#        ['ckd'],
#        ['ckd'],
#        ['ckd'],
#        ['ckd'],
#        ['ckd'],
#        ['ckd'],
#        ['ckd'],
#        ['ckd'],
#        ['ckd'],
#        ['ckd'],
#        ['ckd'],
#        ['ckd'],
#        ['ckd'],
#        ['ckd'],
#        ['ckd'],
#        ['ckd'],
#        ['ckd'],
#        ['ckd'],
#        ['ckd'],
#        ['ckd'],
#        ['ckd'],
#        ['ckd'],
#        ['ckd'],
#        ['ckd'],
#        ['ckd'],
#        ['ckd'],
#        ['ckd'],
#        ['ckd'],
#        ['ckd'],
#        ['ckd'],
#        ['ckd'],
#        ['ckd'],
#        ['ckd'],
#        ['ckd'],
#        ['ckd'],
#        ['ckd'],
#        ['ckd'],
#        ['ckd'],
#        ['ckd'],
#        ['ckd'],
#        ['ckd'],
#        ['ckd'],
#        ['ckd'],
#        ['ckd'],
#        ['ckd'],
#        ['ckd'],
#        ['ckd'],
#        ['ckd'],
#        ['ckd'],
#        ['notckd'],
#        ['notckd'],
#        ['notckd'],
#        ['notckd'],
#        ['notckd'],
#        ['notckd'],
#        ['notckd'],
#        ['notckd'],
#        ['notckd'],
#        ['notckd'],
#        ['notckd'],
#        ['notckd'],
#        ['notckd'],
#        ['notckd'],
#        ['notckd'],
#        ['notckd'],
#        ['notckd'],
#        ['notckd'],
#        ['notckd'],
#        ['notckd'],
#        ['notckd'],
#        ['notckd'],
#        ['notckd'],
#        ['notckd'],
#        ['notckd'],
#        ['notckd'],
#        ['notckd'],
#        ['notckd'],
#        ['notckd'],
#        ['notckd'],
#        ['notckd'],
#        ['notckd'],
#        ['notckd'],
#        ['notckd'],
#        ['notckd'],
#        ['notckd'],
#        ['notckd'],
#        ['notckd'],
#        ['notckd'],
#        ['notckd'],
#        ['notckd'],
#        ['notckd'],
#        ['notckd'],
#        ['notckd'],
#        ['notckd'],
#        ['notckd'],
#        ['notckd'],
#        ['notckd'],
#        ['notckd'],
#        ['notckd'],
#        ['notckd'],
#        ['notckd'],
#        ['notckd'],
#        ['notckd'],
#        ['notckd'],
#        ['notckd'],
#        ['notckd'],
#        ['notckd'],
#        ['notckd'],
#        ['notckd'],
#        ['notckd'],
#        ['notckd'],
#        ['notckd'],
#        ['notckd'],
#        ['notckd'],
#        ['notckd'],
#        ['notckd'],
#        ['notckd'],
#        ['notckd'],
#        ['notckd'],
#        ['notckd'],
#        ['notckd'],
#        ['notckd'],
#        ['notckd'],
#        ['notckd'],
#        ['notckd'],
#        ['notckd'],
#        ['notckd'],
#        ['notckd'],
#        ['notckd'],
#        ['notckd'],
#        ['notckd'],
#        ['notckd'],
#        ['notckd'],
#        ['notckd'],
#        ['notckd'],
#        ['notckd'],
#        ['notckd'],
#        ['notckd'],
#        ['notckd'],
#        ['notckd'],
#        ['notckd'],
#        ['notckd'],
#        ['notckd'],
#        ['notckd'],
#        ['notckd'],
#        ['notckd'],
#        ['notckd'],
#        ['notckd'],
#        ['notckd'],
#        ['notckd'],
#        ['notckd'],
#        ['notckd'],
#        ['notckd'],
#        ['notckd'],
#        ['notckd'],
#        ['notckd'],
#        ['notckd'],
#        ['notckd'],
#        ['notckd'],
#        ['notckd'],
#        ['notckd'],
#        ['notckd'],
#        ['notckd'],
#        ['notckd'],
#        ['notckd'],
#        ['notckd'],
#        ['notckd'],
#        ['notckd'],
#        ['notckd'],
#        ['notckd'],
#        ['notckd'],
#        ['notckd'],
#        ['notckd'],
#        ['notckd'],
#        ['notckd'],
#        ['notckd'],
#        ['notckd'],
#        ['notckd'],
#        ['notckd'],
#        ['notckd'],
#        ['notckd'],
#        ['notckd'],
#        ['notckd'],
#        ['notckd'],
#        ['notckd'],
#        ['notckd'],
#        ['notckd'],
#        ['notckd'],
#        ['notckd'],
#        ['notckd'],
#        ['notckd'],
#        ['notckd'],
#        ['notckd'],
#        ['notckd'],
#        ['notckd'],
#        ['notckd'],
#        ['notckd'],
#        ['notckd'],
#        ['notckd']], dtype=object)

# %% [markdown]
# Principal component analysis is affected by attribute scale so we normalize all the attributes by eliminating the mean and scaling to unit variance.

# %%
x = StandardScaler().fit_transform(x)
x
# Out:
# array([[-0.21003135,  0.25421378,  0.4214856 , ...,  0.60322353,
#         -0.19731401,  0.55004435],
#        [-2.62723421, -1.97247624,  0.4214856 , ..., -0.13278891,
#         -0.90978184,  0.07407304],
#        [ 0.615355  ,  0.25421378, -1.4210744 , ..., -0.99147009,
#         -0.31605865,  0.07407304],
#        ...,
#        [-2.33245337,  0.25421378,  0.4214856 , ...,  1.21656722,
#         -0.67229257,  0.78803001],
#        [-2.03767254, -1.23024623,  1.3427656 , ...,  1.4619047 ,
#         -0.43480329,  1.38299415],
#        [ 0.37953033,  0.25421378,  1.3427656 , ...,  1.70724218,
#         -0.59312947,  1.62097981]])

# %%
pca = PCA(n_components=2)
new_data = pca.fit_transform(x)
pca_ckd = pd.DataFrame(data = new_data, 
                        columns = ['principal component 1', 'principal component 2'])

# %%
pca_ckd_complete = pca_ckd
pca_ckd_complete['class'] = df[['class']]
pca_ckd_complete
# Out:
#      principal component 1  principal component 2   class
# 0                -1.336520               0.054524     ckd
# 1                -0.560117               0.417581     ckd
# 2                 2.728662              -3.408039     ckd
# 3                 2.603753               0.848156     ckd
# 4                 0.595944              -0.127374     ckd
# 5                 0.322512              -0.264924     ckd
# 6                 2.006651               2.924180     ckd
# 7                 0.930501              -3.603416     ckd
# 8                 1.709524              -0.292581     ckd
# 9                 2.650887               1.780220     ckd
# 10                3.045928              -3.970733     ckd
# 11                2.507831              -1.091375     ckd
# 12                2.757153              -1.249881     ckd
# 13                0.131417               1.015474     ckd
# 14                5.107858              -0.682028     ckd
# 15                3.310080               2.220683     ckd
# 16               -0.151955               0.185132     ckd
# 17               -0.275424               0.895821     ckd
# 18                0.751526              -2.267377     ckd
# 19                0.696289               0.620346     ckd
# 20                3.392207               0.662062     ckd
# 21                8.317736              11.513298     ckd
# 22                2.279304               1.787456     ckd
# 23               -0.566834               0.242272     ckd
# 24                1.278998               0.024247     ckd
# 25                0.420770               0.940525     ckd
# 26                0.683363              -0.400255     ckd
# 27                2.755849              -2.775254     ckd
# 28                0.081640              -1.451844     ckd
# 29                0.334434              -0.519698     ckd
# ..                     ...                    ...     ...
# 370              -2.052346               0.023091  notckd
# 371              -3.117119               0.721288  notckd
# 372              -2.350630              -0.708160  notckd
# 373              -1.658926              -0.041522  notckd
# 374              -2.208255              -0.212120  notckd
# 375              -1.863633              -0.163378  notckd
# 376              -2.897595              -0.164774  notckd
# 377              -1.759017               0.110318  notckd
# 378              -1.902543               0.213877  notckd
# 379              -2.543142               0.650955  notckd
# 380              -2.290211               0.180520  notckd
# 381              -2.283511               0.508050  notckd
# 382              -3.202753               0.582416  notckd
# 383              -1.625841               0.348150  notckd
# 384              -1.594193              -0.672450  notckd
# 385              -2.361705              -0.330182  notckd
# 386              -2.877117               0.494129  notckd
# 387              -2.867914               0.829246  notckd
# 388              -2.481788              -0.328855  notckd
# 389              -2.803856               0.361572  notckd
# 390              -2.342396               0.567004  notckd
# 391              -2.877242               0.531681  notckd
# 392              -1.792875              -0.117627  notckd
# 393              -2.434168               0.447324  notckd
# 394              -0.991367              -0.033562  notckd
# 395              -1.790063              -0.272827  notckd
# 396              -3.366305               0.398073  notckd
# 397              -2.451180               0.607525  notckd
# 398              -2.707070               0.922225  notckd
# 399              -2.876721              -0.071159  notckd
#
# [400 rows x 3 columns]

# %%
fig = plt.figure(figsize = (8,8))
ax = fig.add_subplot(1,1,1)
ax.set_xlabel('Principal Component 1', fontsize = 15)
ax.set_ylabel('Principal Component 2', fontsize = 15)
ax.set_title('Principal Component Analysis (2 Components)', fontsize = 20)
targets = ['ckd', 'notckd']
colors = ['r', 'g']
for target, color in zip(targets,colors):
    indicesToKeep = pca_ckd_complete['class'] == target
    ax.scatter(pca_ckd_complete.loc[indicesToKeep, 'principal component 1']
               , pca_ckd_complete.loc[indicesToKeep, 'principal component 2']
               , c = color
               , s = 50)
ax.legend(targets)
ax.grid()

# %%
print("Explained Variance")
print("   Component 1 %3.2f"%(pca.explained_variance_ratio_[0]))
print("   Component 2 %3.2f"%(pca.explained_variance_ratio_[1]))
print("   Total Explained Variance %3.2f"%sum(pca.explained_variance_ratio_))
# Out:
# Explained Variance
#    Component 1 0.32
#    Component 2 0.12
#    Total Explained Variance 0.45

# %%
print("Components")
for i,c in enumerate(pca.components_):
    print("Component %d\t%s"%(i,str(c)))
# Out:
# Components
# Component 0	[ 0.15289174  0.1714626  -0.29923619  0.29776098  0.18959306  0.2095459
#   0.32159826  0.25900731 -0.23468419  0.10639846 -0.39258749 -0.39833149
#   0.10477624 -0.35845123]
# Component 1	[-0.14121477 -0.05941113  0.19837286 -0.16034526 -0.49149458 -0.47442935
#   0.28233545  0.409359   -0.3227177   0.0716598  -0.07791829 -0.05856015
#  -0.27123134 -0.07196698]

# %%
data = np.dot(x,np.transpose(pca.components_))
data[:5,:]
# Out:
# array([[-1.33652044,  0.05452443],
#        [-0.56011686,  0.41758094],
#        [ 2.72866216, -3.40803867],
#        [ 2.60375325,  0.84815621],
#        [ 0.59594435, -0.12737416]])

# %%
pca_ckd.head(5)
# Out:
#    principal component 1  principal component 2 class
# 0              -1.336520               0.054524   ckd
# 1              -0.560117               0.417581   ckd
# 2               2.728662              -3.408039   ckd
# 3               2.603753               0.848156   ckd
# 4               0.595944              -0.127374   ckd

# %% [markdown]
# We can apply PCA with the same number of components as the

# %%
x = df.loc[:, numerical_variables].values
y = df.loc[:,['class']].values
full_pca = PCA()
fitted = full_pca.fit_transform(x)
full_pca.explained_variance_ratio_
# Out:
# array([  9.98644374e-01,   8.84916585e-04,   3.78789547e-04,
#          4.14248396e-05,   2.68896850e-05,   1.35370582e-05,
#          6.47992980e-06,   1.98117823e-06,   9.88507541e-07,
#          2.90938685e-07,   1.84445214e-07,   9.06362812e-08,
#          5.23666135e-08,   2.89626069e-12])

# %% [markdown]
# # t-SNE

# %%
from sklearn.manifold import TSNE
x = df.loc[:, numerical_variables].values
y = df.loc[:,['class']].values

perplexity=50
tsne = TSNE(n_components=2, verbose=1, perplexity=perplexity, n_iter=3000, random_state=1)
# tsne = TSNE(n_components=2, verbose=1, perplexity=10, n_iter=300)
tsne_result = tsne.fit_transform(x)
# Out:
# [t-SNE] Computing 151 nearest neighbors...
# [t-SNE] Indexed 400 samples in 0.000s...
# [t-SNE] Computed neighbors for 400 samples in 0.011s...
# [t-SNE] Computed conditional probabilities for sample 400 / 400
# [t-SNE] Mean sigma: 12.466769
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 51.073067
# [t-SNE] Error after 1150 iterations: 0.139867

# %%
ckd_tsne = pd.DataFrame({'x':tsne_result[:,0], 'y':tsne_result[:,1], 'class':df['class']})

# %%
fig = plt.figure(figsize = (8,8))
ax = fig.add_subplot(1,1,1) 
ax.set_xlabel('x', fontsize = 15)
ax.set_ylabel('y', fontsize = 15)
ax.set_title('t-SNE (2 Components)', fontsize = 20)
targets = ['ckd', 'notckd']
colors = ['r', 'g', 'b']
for target, color in zip(targets,colors):
    indicesToKeep = ckd_tsne['class'] == target
    ax.scatter(ckd_tsne.loc[indicesToKeep,'x'], ckd_tsne.loc[indicesToKeep,'y'], c=color, s=10)
ax.legend(targets)
ax.grid()

# %% [markdown]
# You can try to modify the random_state to generate different t-SNE maps and see if you can find a better representation.
